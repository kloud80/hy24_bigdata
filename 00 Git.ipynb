# %%
import os
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
cd /content/gdrive/MyDrive/Colab Notebooks/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
os.listdir()
# Out:
# ['hy24_bigdata']

# %% [markdown]
# 최초 Git 클론

# %%
# !git clone https://github.com/kloud80/hy24_bigdata.git
# Out:
# fatal: destination path 'hy24_bigdata' already exists and is not an empty directory.

# %% [markdown]
# 덮어쓰기

# %%
cd /content/gdrive/MyDrive/Colab Notebooks/hy24_bigdata/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/hy24_bigdata

# %%
# !git init
# !git remote add origin https://github.com/kloud80/hy24_bigdata.git
# !git pull origin master --allow-unrelated-histories
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/hy24_bigdata/.git/
# error: remote origin already exists.
# fatal: couldn't find remote ref master
